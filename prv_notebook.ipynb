# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # hello
#
# ### hello
#
# #### hello

# %%
import numpy as np

# %%
lista=[1,2,3,4,5,6,7,8]
print (lista)
print(type(lista))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# <class 'list'>

# %%
np_lista=np.array([1,2,3,4,5,6,7,8])
np_lista=np.array(np_lista)
print(np_lista)
print(type(np_lista))
# Out:
# [1 2 3 4 5 6 7 8]
# <class 'numpy.ndarray'>

# %%
print(np_lista[0])
np_lista[2:6]
# Out:
# 1
# array([3, 4, 5, 6])

# %%
matrix=[[1,2,3],[4,5,3],[7,8,9]]
np_matrix=np.array(matrix)
print(np_matrix[1][2])
# Out:
# 3

# %%
rand=np.random.randint(5,500, size=30)

print(rand)
# Out:
# [213  77 257 405 487 278  61 447 117 324 182 294 430 194  97 419 354 418
#  283 498 146 377 181 146 270 340 323 305 475  86]

# %%
rand_filte =rand>250
rand[rand_filte]
rand[rand>250]
# Out:
# array([257, 405, 487, 278, 447, 324, 294, 430, 419, 354, 418, 283, 498,
#        377, 270, 340, 323, 305, 475], dtype=int32)

# %%
print(f"SUM:{rand.sum()}")
print(f"MAX:{rand.max()}")
print(f"MIN:{rand.min()}")
print(f"mean:{rand.mean()}")
# Out:
# SUM:8484
# MAX:498
# MIN:61
# mean:282.8
